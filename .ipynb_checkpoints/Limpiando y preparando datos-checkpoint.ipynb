# %% [markdown]
# # Limpieza de datos

# %%
#Importando lobrerias necesarias.
import pandas as pd
import numpy as np
import re
import selenium

# %%
datos = pd.read_csv("Datos/PredialZacatepec.csv", encoding = "ANSI")
predial = pd.DataFrame(datos)

# %%
predial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8896 entries, 0 to 8895
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   clave               8896 non-null   object
#  1   claveanterior       81 non-null     object
#  2   cuentapredial       8896 non-null   object
#  3   propietario         8891 non-null   object
#  4   domicilio           8790 non-null   object
#  5   colonia             8328 non-null   object
#  6   cp                  1234 non-null   object
#  7   domnotificacion     8347 non-null   object
#  8   colnotificacion     7496 non-null   object
#  9   ciudadnotificacion  7997 non-null   object
#  10  tipopredio          8842 non-null   object
#  11  sterreno            8896 non-null   float64
#  12  sconstruccion       8896 non-null   float64
#  13  vterreno            8896 non-null   float64
#  14  vconstruccion       8896 non-null   float64
# ...

# %%
#limpiamos las columnas no reelevantes.
predial.drop(["claveanterior","cuentapredial","domnotificacion","colnotificacion","ciudadnotificacion","estado","cp"], axis = 1, inplace = True)

# %% [markdown]
# ## Sexo contribuyente

# %%
predial_sex= predial.copy()

# %%
predial_sex.drop(predial_sex[predial_sex["tipopredio"]=="EXCENTOS"].index,axis = 0, inplace = True)
predial_sex.drop(predial_sex[predial_sex["propietario"].isnull()].index, axis = 0, inplace = True)

# %%
count = 0
for i in predial_sex["propietario"].index:
    predial_sex["propietario"][i] = str(predial_sex["propietario"][i]).lower() 
    if "zacatepec" and "en rep" and "gobierno" and "escuela" and "jardin" and "secuendaria" and "unidad" and "ayuntamiento" and "s.a" and "c.v" in predial_sex["propietario"][i]:
        predial_sex["propietario"][i] = "Persona moral"
    else:
        predial_sex["propietario"][i] = re.sub("y\s...+" or "y/o\s...+","",str(predial_sex["propietario"][i]))
    print(predial_sex["propietario"][i])
# Out:
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# castillo sopeñas gregorio
# unidad real de galeana (concepcion rivera renteria)
# maria lucio pineda
# radilla ocampo  adalbertha cruz
# rodriguez de aranda maria
# medero mendoza timoteo
# flores hernandez humberto
# navarro cervantes rogelio
# ocampo alvarez de shuk
# ...

# %%
lista = ["unidad","galeana"]
if str(lista) in predial_sex["propietario"][1]:
    print(predial_sex["propietario"][1])

# %%
if "unidad" in predial_sex["propietario"][1]:
    predial_sex["propietario"][1]
# Out:
# 'unidad real de galeana (concepcion rivera renteria)'

# %%
for i in predial_sex["propietario"].index:
    nombre = predial_sex["propietario"][i].split() 
    predial_sex["primero"][i] = nombre[0]  
    predial_sex["ultimo"][i] = nombre[-1]
# Out:
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for i in predial_sex["ultimo"].index:
    print(predial_sex["ultimo"][i])
# Out:
# GREGORIO
# RENTERIA)
# PINEDA
# CRUZ
# MARIA
# TIMOTEO
# HUMBERTO
# ROGELIO
# CARLOTA
# ROSALIO
# FRANCISCO
# REGINO
# ESTHER
# LUIS
# EPIFANIO
# DARIO
# LEOVIGILDA
# C.V.
# C.V.
# C.V.
# YOLANDA
# ARACELI
# RIVERA
# COND.
# ALBERTO
# CRISTINO
# GASCA
# OMAR
# FLORES
# CARMEN
# JOEL
# COLUMBA
# YOLANDA
# YOLANDA
# MARLONG
# OFELIA
# FRANCISCO
# JESUS
# ELDER
# IRMA
# TORRES
# DURAN
# BENITEZ
# ISMAEL
# MARTHA
# RAMIREZ)
# SILVIA
# RAMIREZ
# PÉREZ
# CONCEPCION
# BANDERA
# LOPEZ
# LOPEZ
# MERCEDES
# VALDEZ
# VERONICA
# FDRJO/2210/2013
# OCAMPO
# OCAMPO
# SILVIA
# LILI
# ROMAN
# GOMEZ
# MADRID
# RENE
# MENDOZA
# CARLOS
# MARINA
# SANCHEZ
# PEDRO
# CABRERA
# GAYTAN
# ESPIN
# ROLANDO
# JOVITA
# DIAZ
# YURY
# PALACIOS
# MEDINA
# ALBARRAN
# HERNANDEZ
# MARIA
# HUITRON
# RAMIREZ
# AVILA
# PEÑA
# GASCA
# ROQUE
# JASMIN
# VELAZQUEZ
# ROJAS
# DURAN
# VELAZQUEZ
# OCAMPO
# CANSECO
# RAMIREZ
# RAMIREZ
# MARIA
# ANDRES
# JESUS
# DIAZ
# CONTRERAS
# RAMIREZ
# RAMIREZ
# MONTES
# MONTES
# GONZALEZ
# ...

# %%
lista = []
lista = predial_sex["ultimo"].unique()
len(lista)
#for i in lista:
 #   print(i)
# Out:
# 1750

# %%
x = predial_sex["propietario"][0].split()
print(x[0])
# Out:
# CASTILLO

# %%
(predial["tipopredio"] == "EXCENTOS").sum()
# Out:
# 42

# %%
for i in predial["domicilio"].index:
    print(predial["domicilio"][i])
# Out:
# av. tecnológico num. 1 esq. j. trinidad ruiz
# morelos #31 esq. cuauhtemoc
# galeana esq. allende
# esq. hidalgo y morelos 48
# calle sin nombre esq. calle sin nombre
# morelos esq.  calle s/nombre
# esq. carrt, zacatepec/tlaltizapan
# francisco mendoza esq. felipe vaquero #  8
# jesus morales #6, esq. felipe vaquero
# felipe vaquero esq. e. zapata
# otilio nontaño esq. e. zapata
# emigdio marmolejo c.f. vazquez esq. e. zapata
# gabriel tepepa esq. e. marmolejo
# gabriel tepepa esq.emigdio marmolejo
# felipe vaquero esq. emigdio marmolejo
# cleotilde sosa esq. emigdio marmolejo no. 48
# cleotilde sosa esq. gabriel tepepa
# otilio montñao esq. felipe vaquero
# cleotilde sosa s/n esq. otilio montaño
# e. marmolejo esq. felipe vaquero no.27
# av. e. zapata esq. otilio montaño # 61
# otilio montaño #57 esq. cleotilde sosa
# emiliano zapata esq. cleotilde sosa
# av. emiliano zapata esq. felipe vaquero
# fco. mendoza esq. f. vaquero
# felipe vaquero esq. jesus morales
# ...

# %%
for i in predial["domicilio"].index:
    predial["domicilio"][i] = str(predial["domicilio"][i]).lower()
    print(predial["domicilio"][i]) ELIMINAR A LOS QUE NO TENGAN NUMERO O DIGAN ESQ
# Out:
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 20 de noviembre #045
# av. escuadron 201 s/n
# av. revolucion no.57
# av. tecnológico num. 1 esq. j. trinidad ruiz
# cjon. fermin umaña num. 1
# carretera jojutla-galeana
# niños heroes #36
# av. revolucion s/n
# matamoros 3
# morelos #31 esq. cuauhtemoc
# galeana esq. allende
# buenos aires
# francisco sarabia no.8
# pedro ascencio num. 9
# esq. hidalgo y morelos 48
# francisco i. madero
# av. escuadron 201 #45
# av. escuadron 201 #47
# av. escuadron 201 #49
# dr luis mora #2
# morelos s/n
# av. instituto tecnologico s/n, zacatepec
# venustiano carranza nº 72
# jose maria morelos
# parcela num 150 z-1 p-1
# calle s/n
# campo san martin
# emiliano zapata s/n
# ...

# %%
for i in predial["domicilio"].index:
    calle = []
    predial["domicilio"][i] = re.sub("#\d+" or "s/n" or "no.\d+" or "num.\d+" or "num\s...+" or 
                                     "nº\s...+" or "#\d+...+"," ",str(predial["domicilio"][i]))
    print(predial["domicilio"][i])
# Out:
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 20 de noviembre
# carretera jojutla-alpuyeca
# av. escuadron 201 s/n
# av. revolucion no.57
# av. tecnológico num. 1 esq. j. trinidad ruiz
# cjon. fermin umaña num. 1
# carretera jojutla-galeana
# niños heroes
# av. revolucion s/n
# matamoros 3
# morelos   esq. cuauhtemoc
# galeana esq. allende
# buenos aires
# francisco sarabia no.8
# nan
# pedro ascencio num. 9
# esq. hidalgo y morelos 48
# francisco i. madero
# av. escuadron 201
# av. escuadron 201
# av. escuadron 201
# dr luis mora
# morelos s/n
# av. instituto tecnologico s/n, zacatepec
# venustiano carranza nº 72
# jose maria morelos
# parcela num 150 z-1 p-1
# calle s/n
# ...

# %%
predial["domicilio"][520]
# Out:
# 'Carlos'

# %%
for i in predial["domicilio"]:

    print(i)
# Out:
# 20 DE NOVIEMBRE #045
# AV. ESCUADRON 201 S/N
# AV. REVOLUCION No.57
# AV. TECNOLÓGICO NUM. 1 ESQ. J. TRINIDAD RUIZ
# CJON. FERMIN UMAÑA NUM. 1
# CARRETERA JOJUTLA-GALEANA
# NIÑOS HEROES #36
# AV. REVOLUCION S/N
# MATAMOROS 3
# MORELOS #31 ESQ. CUAUHTEMOC
# GALEANA ESQ. ALLENDE
# BUENOS AIRES
# FRANCISCO SARABIA NO.8
# PEDRO ASCENCIO NUM. 9
# ESQ. HIDALGO Y MORELOS 48
# FRANCISCO I. MADERO
# AV. ESCUADRON 201 #45
# AV. ESCUADRON 201 #47
# AV. ESCUADRON 201 #49
# DR LUIS MORA #2
# MORELOS S/N
# AV. INSTITUTO TECNOLOGICO S/N, ZACATEPEC
# VENUSTIANO CARRANZA Nº 72
# JOSE MARIA MORELOS
# PARCELA NUM 150 Z-1 P-1
# CALLE S/N
# CAMPO SAN MARTIN
# EMILIANO ZAPATA S/N
# LOTE TERRENO "CAMPO CHICOMOZUELO"
# AV. DR. JOSE LUIS MORA LOTE 306
# CALZADA INSTITUTO TECNOLOGICO #5
# GUADALUPE VICTORIA # 13
# AV. JOSE LUIS MORA S/N
# CALLE SIN NOMBRE ESQ. CALLE SIN NOMBRE
# CARRETERA ZACATEPEC-TLALTIZAPAN
# CARRETERA ZACATEPEC- TLALTIZAPAN
# CALLE 14 DE FEBRERO NUM. 3
# MORELOS ESQ.  CALLE S/NOMBRE
# ...

# %%
predial["domicilio"][19].replace("#","num ")
#predial["domicilio"][19].replace(".", "")
# Out:
# 'AV. ESCUADRON 201 num 47'

# %%
predial["sterreno"] = predial["sterrene"].dtype(float32)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sterrene'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-256-b6e47e3e40c3> in <module>
# ...

# %%
predial["sterreno"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-253-d79fa44a9174> in <module>
# ----> 1 predial["sterreno"].dtype()
#
# TypeError: 'numpy.dtype' object is not callable

# %%
navegador = webdriver.Chrome()
navegador.maximize_window()
navegador.get(https://www.google.com/maps/search/coworking+in+cambridge+boston/@42.3788644,-71.1473991,13z/data=!3m1!4b1')

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.geocode("175 5th Avenue NYC")
print(location.address)
#Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
#>>> print((location.latitude, location.longitude))
#(40.7410861, -73.9896297241625)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-273-1f1e38702a35> in <module>
#       1 from geopy.geocoders import Nominatim
# ----> 2 geolocator = Nominatim()
#       3 location = geolocator.geocode("175 5th Avenue NYC")
#       4 print(location.address)
#       5 #Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
#
# ~\Anaconda3\lib\site-packages\geopy\geocoders\nominatim.py in __init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     112                 'overriding the default `user_agent`: '
#     113                 '`geopy.geocoders.options.default_user_agent = "my-application"`.'
# --> 114                 % self.headers['User-Agent']
#     115             )
#     116
#
# ...

# %%
import geocoder

# %%
loc = geocoder.mapbox("Av Revolucion No 57, Zacatepec, Morelos")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-62da67adc5fd> in <module>
# ----> 1 loc = geocoder.mapbox("Av Revolucion No 57, Zacatepec, Morelos")
#
# ~\Anaconda3\lib\site-packages\geocoder\api.py in mapbox(location, **kwargs)
#     243         > batch
#     244     """
# --> 245     return get(location, provider='mapbox', **kwargs)
#     246
#     247
#
# ~\Anaconda3\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~\Anaconda3\lib\site-packages\geocoder\base.py in __init__(self, location, **kwargs)
#     378
#     379         # check validity of provider key
# --> 380         provider_key = self._get_api_key(kwargs.pop('key', ''))
#     381
# ...

# %%
loc
# Out:
# <[REQUEST_DENIED] Google - Geocode [empty]>

# %%
from pygeocoder import Geocoder

# %%
#Eliminamos las filas cuya superficie del terreno sea igual a cero, ya que contien datos insignificantes.
#Tambien eliminamos los predios cuya direccion no aparece.

predial.drop(predial[predial["sterreno"]==0].index,axis = 0, inplace = True)
predial.drop(predial[predial["domicilio"].isnull()].index, axis = 0, inplace = True)
for i in predial["domicilio"].index:
    predial["domicilio"][i] = str(predial["domicilio"][i]).lower()
    if "esq" in predial["domicilio"][i]:
        pass
    else:      
        if "sin nombre" or "s/n" in predial["domicilio"][i]:
            predial.drop(i, axis = 0,inplace = True)
# Out:
# C:\Users\Tomaas\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
results = Geocoder.geocode("Av Revolucion No 57, Zacatepec, Morelos")
# Out:
# ---------------------------------------------------------------------------
# GeocoderError                             Traceback (most recent call last)
# <ipython-input-142-fe1d122f6a72> in <module>
# ----> 1 results = Geocoder.geocode("Av Revolucion No 57, Zacatepec, Morelos")
#
# ~\Anaconda3\lib\site-packages\pygeocoder.py in geocode(self, address, sensor, bounds, region, language, components)
#     127             return GeocoderResult(self.get_data(params=params))
#     128         else:
# --> 129             return GeocoderResult(Geocoder.get_data(params=params))
#     130
#     131     @omnimethod
#
# ~\Anaconda3\lib\site-packages\pygeocoder.py in get_data(self, params)
#     210
#     211         if response_json['status'] != GeocoderError.G_GEO_OK:
# --> 212             raise GeocoderError(response_json['status'], response.url)
#     213         return response_json['results']
#     214
#
# GeocoderError: Error REQUEST_DENIED
# ...

# %%
from geopy.geocoders import Nominatim
import time
import math

# %%
geo = Nominatim(user_agent = "GeoLoc")

# %%
loc = geo.geocode("colonia centro, zacatepec morelos")
print(loc)
# Out:
# Carretera Federal Zacatepec-Zapata, Emiliano Zapata Centro, Emiliano Zapata, Morelos, 62765, México

# %%
print(loc.latitude,loc.longitude)
# Out:
# 18.8364266 -99.1835826
